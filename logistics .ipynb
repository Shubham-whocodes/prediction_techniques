# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sb
from sklearn import linear_model
data = pd.read_csv(r'/Users/shubham_kumar/Desktop/ml/iris.csv')
data['variety'].replace({'Setosa':'1','Versicolor':'2','Virginica':'3'}, inplace =True)
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width variety
# 0             5.1          3.5           1.4          0.2       1
# 1             4.9          3.0           1.4          0.2       1
# 2             4.7          3.2           1.3          0.2       1
# 3             4.6          3.1           1.5          0.2       1
# 4             5.0          3.6           1.4          0.2       1
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       3
# 146           6.3          2.5           5.0          1.9       3
# 147           6.5          3.0           5.2          2.0       3
# 148           6.2          3.4           5.4          2.3       3
# 149           5.9          3.0           5.1          1.8       3
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
xtr,xte,ytr,yte = train_test_split(data[['sepal.length','sepal.width','petal.length','petal.width']],data[['variety']],test_size = 0.2)

# %%
model  = linear_model.LogisticRegression()

# %%
model.fit(xtr,ytr)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(xte)
# Out:
# array(['2', '3', '2', '3', '3', '2', '1', '3', '1', '3', '2', '1', '3',
#        '2', '2', '1', '1', '2', '3', '3', '1', '2', '1', '1', '1', '3',
#        '1', '3', '2', '2'], dtype=object)

# %%
model.score(xte,yte)
# Out:
# 0.9666666666666667

# %%
sb.pairplot(data[['sepal.length','sepal.width','petal.length','petal.width','variety']],hue='Species')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species'
#
# ...
